# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv("Salary_Data.csv")

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
dataset.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
sns.scatterplot(x=dataset["Age"],y=dataset["YearsExperience"])
# Out:
# <Axes: xlabel='Age', ylabel='YearsExperience'>

# %%
x=dataset[["YearsExperience","Age"]]
y=dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2,random_state=45)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[1.1,21]])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35574.53754831])

# %%
lr.feature_names_in_
# Out:
# array(['YearsExperience', 'Age'], dtype=object)

# %%
(lr.score(x_test,y_test))*100
# Out:
# 93.95450238104219
